# %%
import psycopg2
import psycopg2.extras

hostname = 'localhost'
database = 'demo'
username = 'postgres'
pwd = 'anurag'
port_id = 5432
conn = None

try:
    with psycopg2.connect(
                host = hostname,
                dbname = database,
                user = username,
                password = pwd,
                port = port_id) as conn:

        with conn.cursor(cursor_factory=psycopg2.extras.DictCursor) as cur:

            cur.execute('DROP TABLE IF EXISTS employee')

            create_script = ''' CREATE TABLE IF NOT EXISTS employee (
                                    id      int PRIMARY KEY,
                                    name    varchar(40) NOT NULL,
                                    salary  int,
                                    dept_id varchar(30)) '''
            cur.execute(create_script)

#            insert_script  = 'INSERT INTO employee (id, name, salary, dept_id) VALUES (%s, %s, %s, %s)'
#            insert_values = [(1, 'James', 12000, 'D1'), (2, 'Robin', 15000, 'D1'), (3, 'Xavier', 20000, 'D2')]
#            for record in insert_values:
#                cur.execute(insert_script, record)

#            update_script = 'UPDATE employee SET salary = salary + (salary * 0.5)'
#            cur.execute(update_script)

#            delete_script = 'DELETE FROM employee WHERE name = %s'
#            delete_record = ('James',)
#            cur.execute(delete_script, delete_record)

#            cur.execute('SELECT * FROM EMPLOYEE')
#            for record in cur.fetchall():
#                print(record['name'], record['salary'])

except Exception as error:
    print(error)
finally:
    if conn is not None:
        conn.close()

# %%
# %ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number is 762C-8E4E
#
#  Directory of C:\Users\ashwa
#
# 06-04-2022  11:03    <DIR>          .
# 06-04-2022  11:03    <DIR>          ..
# 14-12-2021  09:44    <DIR>          .anaconda
# 11-11-2021  18:58    <DIR>          .android
# 05-03-2022  11:34    <DIR>          .aws
# 05-03-2022  11:34    <DIR>          .azure
# 06-04-2022  12:26             4,934 .bash_history
# 14-01-2022  12:38    <DIR>          .conda
# 14-12-2021  09:45                43 .condarc
# 14-12-2021  09:46    <DIR>          .continuum
# 16-02-2021  11:26            31,987 .dbshell
# 29-03-2022  12:51    <DIR>          .docker
# 01-04-2022  12:14    <DIR>          .eclipse
# 30-03-2022  11:39                63 .gitconfig
# 01-06-2021  10:46    <DIR>          .idea-build
# 06-04-2022  09:37    <DIR>          .ipynb_checkpoints
# 27-10-2020  19:45    <DIR>          .ipython
# 08-06-2021  13:12    <DIR>          .ivy2
# 14-12-2021  10:15    <DIR>          .jupyter
# 12-08-2021  23:09    <DIR>          .keras
# 30-03-2022  12:40                20 .lesshst
# 24-02-2022  12:38    <DIR>          .m2
# 02-01-2021  12:31    <DIR>          .matplotlib
# 08-12-2020  11:38                 0 .mongorc.js
# 22-08-2021  16:55    <DIR>          .Origin
# 24-02-2022  17:24               111 .python_history
# 22-08-2021  16:55    <DIR>          .QtWebEngineProcess
# 08-06-2021  13:11    <DIR>          .sbt
# 10-06-2021  10:33             4,176 .scala_history
# 09-06-2021  12:36             1,468 .scala_history_jline3
# 30-03-2022  12:28             1,184 .viminfo
# 31-08-2021  17:21    <DIR>          .VirtualBox
# 02-08-2021  14:38             6,901 -1.14-windows.xml
# 11-04-2021  11:45            58,639 1132200246 Decision Tree 2.ipynb
# 22-10-2021  15:58           177,266 1132200482.ipynb
# 06-10-2021  12:50            22,600 1132200482_AnuragThakur.ipynb
# 16-05-2021  21:59           281,273 1132200482_AnuragThakur_Assignment10_PCA.ipynb
# 16-05-2021  21:59           370,049 1132200482_AnuragThakur_Assignment11_Naive Baye's.ipynb
# 30-12-2020  13:43           298,731 1132200482_anuragthakur_ML_3&4.ipynb
# 01-06-2021  10:14    <DIR>          metastore_db
# 10-12-2020  18:09           123,536 ML lab 1.ipynb
# 10-12-2020  23:22            87,982 ML_ASSIGNMENT1_Anurag.ipynb
# 07-03-2022  12:29            61,759 Mobile_Data_Consumer (1).ipynb
# 21-03-2022  13:47             3,829 Mobile_Data_Producer (1).ipynb
# 06-04-2022  11:03            51,901 Mobile_Data_Producer (2).ipynb
# 28-02-2022  11:57             1,466 mqtt_kafka_producer.py.ipynb
# 02-03-2022  12:10               379 mqtt_publish1.py
# 02-03-2022  12:10               374 mqtt_publish2.py
# 02-03-2022  12:10               377 mqtt_subscribe.py
# 05-04-2021  20:53    <DIR>          Music
# 07-12-2021  15:55    <DIR>          NCH Software Suite
# 23-07-2021  23:03                45 nuuid.ini
# 06-04-2022  08:59    <DIR>          OneDrive
# 26-06-2021  19:53        22,512,005 onyxdatachallenge.ipynb
# 08-06-2021  10:50    <DIR>          Pictures
# 04-10-2021  12:15             4,638 pipeline.config
# 15-12-2021  08:46    <DIR>          PycharmProjects
# 18-01-2021  10:25             2,487 python connectivity.ipynb
# 01-04-2022  11:41             2,457 Python OOPS Anurag Thakur.ipynb
# 25-02-2022  13:23            19,823 Python_Assessment_AnuragThakur.ipynb
# 01-04-2022  21:16             4,080 Python_ETL_Notebook.ipynb
# 30-03-2022  12:59             1,444 Python_Q1_AnuragThakur.ipynb
# 06-04-2022  10:08             3,046 Python_To_PostgreSQL.ipynb
# 06-07-2021  11:44               946 pytorch.ipynb
# 02-03-2022  12:09               224 readme.md
# 05-04-2021  20:53    <DIR>          Saved Games
# 05-04-2021  20:53    <DIR>          Searches
# 02-03-2022  21:43             3,762 settings.json
# 30-03-2022  11:36    <DIR>          source
# 05-07-2021  12:19           135,526 Time_Series_Anomaly_Nifty_BajajFinanace.ipynb
# 04-10-2021  12:15             6,826 train.py
# 04-10-2021  12:16             9,688 trainer_test.py
# 19-05-2021  13:48         3,712,651 Uber.ipynb
# 04-11-2020  22:50    <DIR>          Untitled Folder
# 30-06-2021  20:47    <DIR>          Untitled Folder 1
# 30-06-2021  20:47    <DIR>          Untitled Folder 2
# 01-10-2021  09:53    <DIR>          Untitled Folder 3
# 01-10-2021  09:53    <DIR>          Untitled Folder 4
# 17-12-2020  13:44             8,951 Untitled.ipynb
# 14-01-2021  14:44                 0 untitled.txt
# 17-12-2020  15:03             2,689 Untitled1.ipynb
# 25-02-2021  10:08                 0 untitled1.txt
# 12-01-2022  20:44             1,165 Untitled10.ipynb
# 25-02-2022  12:43                72 Untitled11.ipynb
# 05-04-2022  19:02            11,033 Untitled12.ipynb
# 25-02-2021  10:07                72 Untitled2.ipynb
# 31-05-2021  09:01                 0 untitled2.txt
# 05-04-2021  12:42             9,944 Untitled3.ipynb
# 05-06-2021  20:14           129,909 Untitled4.ipynb
# 01-07-2021  11:39             2,806 Untitled5.ipynb
# 25-09-2021  15:11                72 Untitled6.ipynb
# 25-09-2021  19:15             5,917 Untitled7.ipynb
# 14-10-2021  19:50             3,675 Untitled8.ipynb
# 29-10-2021  21:29             1,009 Untitled9.ipynb
# 23-07-2021  23:03                53 useruid.ini
# 14-10-2021  19:16            11,928 utf-8''utils.py
# 29-03-2022  12:46    <DIR>          Videos
# 05-12-2020  19:30    <DIR>          VirtualBox VMs
# 31-08-2021  17:55    <DIR>          vmlogs
#              100 File(s)  1,763,993,664 bytes
#               51 Dir(s)  42,333,978,624 bytes free
